# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %%
df = pd.read_csv('zhiwei_results/modularity_undiffused_out.txt',sep="\t",index_col=False)
# df = df[df['CID']==30]
# df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
#         | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
# df = df[(df['Method'] == "node2vec_128d_p1_q1") | (df['Method'] == "node2vec_128d_p1_q2") \
#         | (df['Method'] == "node2vec_128d_p1_q0.5") | (df['Method'] == "node2vec_128d_p2_q1") \
#         | (df['Method'] == "node2vec_128d_p0.5_q1")]
# df = df[(df['Method'] == "node2vec_256d_p1_q1") | (df['Method'] == "node2vec_256d_p1_q2") \
#         | (df['Method'] == "node2vec_256d_p1_q0.5") | (df['Method'] == "node2vec_256d_p2_q1") \
#         | (df['Method'] == "node2vec_256d_p0.5_q1")]
df = df[(df['Method'] == "node2vec_64d_p1_q1") | (df['Method'] == "node2vec_64d_p1_q2") \
        | (df['Method'] == "node2vec_64d_p1_q0.5") | (df['Method'] == "node2vec_64d_p2_q1") \
        | (df['Method'] == "node2vec_64d_p0.5_q1")]
#df = df[(df['Method'] == "VGAE_64d") | (df['Method'] == "VGAE_128d") | (df['Method'] == "VGAE_256d")]

# %%
df.head()
# Out:
#                      Method  CID  \
# 9350  node2vec_256d_p0.5_q1   10
# 9351  node2vec_256d_p0.5_q1   20
# 9352  node2vec_256d_p0.5_q1   30
# 9353  node2vec_256d_p0.5_q1   40
# 9354  node2vec_256d_p0.5_q1   50
#
#                                                Cellline     Score
# 9350  breast_variant_human_mammary_epithelial_cells_...  0.526250
# 9351  breast_variant_human_mammary_epithelial_cells_...  0.539985
# 9352  breast_variant_human_mammary_epithelial_cells_...  0.514314
# 9353  breast_variant_human_mammary_epithelial_cells_...  0.532628
# 9354  breast_variant_human_mammary_epithelial_cells_...  0.505203

# %%
# ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_128d_p1_q1", "node2vec_128d_p1_q2", \
#                                                                     "node2vec_128d_p1_q0.5", "node2vec_128d_p2_q1", \
#                                                                     "node2vec_128d_p0.5_q1"])
# ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_256d_p1_q1", "node2vec_256d_p1_q2", \
#                                                                     "node2vec_256d_p1_q0.5", "node2vec_256d_p2_q1", \
#                                                                     "node2vec_256d_p0.5_q1"])
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_64d_p1_q1", "node2vec_64d_p1_q2", \
                                                                    "node2vec_64d_p1_q0.5", "node2vec_64d_p2_q1", \
                                                                    "node2vec_64d_p0.5_q1"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='right')
ax.set_title("Cell-type Specific Network")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('pq_results/modularity_pq_undiffused_64d.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "node2vec_64d_p1_q1") | (df['Method'] == "node2vec_64d_p1_q2") \
        | (df['Method'] == "node2vec_64d_p1_q0.5") | (df['Method'] == "node2vec_64d_p2_q1") \
        | (df['Method'] == "node2vec_64d_p0.5_q1")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_64d_p1_q1", "node2vec_64d_p1_q2", \
                                                                    "node2vec_64d_p1_q0.5", "node2vec_64d_p2_q1", \
                                                                    "node2vec_64d_p0.5_q1"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('pq_results/AMI_pq_0.5_64d.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "node2vec_128d_p1_q1") | (df['Method'] == "node2vec_128d_p1_q2") \
        | (df['Method'] == "node2vec_128d_p1_q0.5") | (df['Method'] == "node2vec_128d_p2_q1") \
        | (df['Method'] == "node2vec_128d_p0.5_q1")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_128d_p1_q1", "node2vec_128d_p1_q2", \
                                                                    "node2vec_128d_p1_q0.5", "node2vec_128d_p2_q1", \
                                                                    "node2vec_128d_p0.5_q1"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('pq_results/AMI_pq_0.5_128d.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "node2vec_256d_p1_q1") | (df['Method'] == "node2vec_256d_p1_q2") \
        | (df['Method'] == "node2vec_256d_p1_q0.5") | (df['Method'] == "node2vec_256d_p2_q1") \
        | (df['Method'] == "node2vec_256d_p0.5_q1")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_256d_p1_q1", "node2vec_256d_p1_q2", \
                                                                    "node2vec_256d_p1_q0.5", "node2vec_256d_p2_q1", \
                                                                    "node2vec_256d_p0.5_q1"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('pq_results/AMI_pq_0.5_256d.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "VGAE_64d") | (df['Method'] == "VGAE_128d") | (df['Method'] == "VGAE_256d")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["VGAE_64d", "VGAE_128d", "VGAE_256d"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('k_results/AMI_k_0.5_VGAE.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "DeepWalk_64d") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "DeepWalk_256d")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["DeepWalk_64d", "DeepWalk_128d", "DeepWalk_256d"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('k_results/AMI_k_0.5_DeepWalk.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "node2vec_64d_p1_q1") | (df['Method'] == "node2vec_128d_p1_q1") | (df['Method'] == "node2vec_256d_p1_q1")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["node2vec_64d_p1_q1", "node2vec_128d_p1_q1", "node2vec_256d_p1_q1"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('k_results/AMI_k_0.5_node2vec.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[(df['Method'] == "Graphsage_64d") | (df['Method'] == "Graphsage_128d") | (df['Method'] == "Graphsage_256d")]
ax = sns.boxplot(x="CID",y="Score",hue="Method",data=df, hue_order=["Graphsage_64d", "Graphsage_128d", "Graphsage_256d"])
ax.set_xticklabels(ax.xaxis.get_ticklabels(),ha='center')
ax.set_title("Simulated Network with alpha = 0.5")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("# of clusters")
lgd = ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.subplots_adjust(bottom=0.35,left=0.15)
plt.savefig('k_results/AMI_k_0.5_Graphsage.png',bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
df = pd.read_csv('zhiwei_results/silhouette_undiffused_out.txt',sep="\t",index_col=False)
df = df[df['CID']==50]
df = df[(df['Method'] == "node2vec_128d_p0.5_q1") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_256d") \
        | (df['Method'] == "Graphsage_64d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Cell-type Specific Network with optimal k = 50")
ax.set_ylabel("Silhouette Scores")
ax.set_xlabel("Methods")
plt.savefig('box_silhouette_undiffused.png',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/modularity_undiffused_out.txt',sep="\t",index_col=False)
df = df[df['CID']==50]
df = df[(df['Method'] == "node2vec_128d_p0.5_q1") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_256d") \
        | (df['Method'] == "Graphsage_64d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Cell-type Specific Network with optimal k = 50")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("Methods")
plt.savefig('box_modularity_undiffused.png',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/DBI_undiffused_out.txt',sep="\t",index_col=False)
df = df[df['CID']==50]
df = df[(df['Method'] == "node2vec_128d_p0.5_q1") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "vgae_256d") \
        | (df['Method'] == "graphsage_64d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Cell-type Specific Network with optimal k = 50")
ax.set_ylabel("DBI Scores")
ax.set_xlabel("Methods")
plt.savefig('box_DBI_undiffused.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/silhouette_asd_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("ASD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("Silhouette Scores")
ax.set_xlabel("Methods")
plt.savefig('box_silhouette_asd.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/modularity_asd_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("ASD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("Methods")
plt.savefig('box_modularity_asd.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/DBI_asd_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "vgae_128d") \
        | (df['Method'] == "graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("ASD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("DBI Scores")
ax.set_xlabel("Methods")
plt.savefig('box_DBI_asd_10.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/silhouette_cad_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_64d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("CAD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("Silhouette Scores")
ax.set_xlabel("Methods")
plt.savefig('box_silhouette_cad.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/modularity_cad_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "VGAE_64d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("CAD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("Methods")
plt.savefig('box_modularity_cad.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/DBI_cad_out.txt',sep="\t",index_col=False)
df = df[df['CID']==10]
df = df[(df['Method'] == "node2vec_256d_p1_q2") | (df['Method'] == "DeepWalk_64d") | (df['Method'] == "vgae_64d") \
        | (df['Method'] == "graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("CAD Phenotype-Specific Network with optimal k = 10")
ax.set_ylabel("DBI Scores")
ax.set_xlabel("Methods")
plt.savefig('box_DBI_cad_10.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/silhouette_0.1_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.1 and optimal k = 30")
ax.set_ylabel("Silhouette Scores")
ax.set_xlabel("Methods")
plt.savefig('box_silhouette_0_1.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/modularity_0.1_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.1 and optimal k = 30")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("Methods")
plt.savefig('box_modularity_0_1.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/AMI_0.1_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.1 and optimal k = 30")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("Methods")
plt.savefig('box_ami_0_1.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/silhouette_0.5_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.5 and optimal k = 30")
ax.set_ylabel("Silhouette Scores")
ax.set_xlabel("Methods")
plt.savefig('box_silhouette_0_5.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/modularity_0.5_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.5 and optimal k = 30")
ax.set_ylabel("Modularity Scores")
ax.set_xlabel("Methods")
plt.savefig('box_modularity_0_5.pdf',bbox_inches="tight")

# %%
df = pd.read_csv('zhiwei_results/AMI_0.5_out.txt',sep="\t",index_col=False)
df = df[df['CID']==30]
df = df[(df['Method'] == "node2vec_128d_p1_q2") | (df['Method'] == "DeepWalk_128d") | (df['Method'] == "VGAE_128d") \
        | (df['Method'] == "Graphsage_256d") | (df['Method'] == "spectral_clustering")]
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Simulated Network with alpha = 0.5 and optimal k = 30")
ax.set_ylabel("AMI Scores")
ax.set_xlabel("Methods")
plt.savefig('box_ami_0_5.pdf',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/DeepWalk_64d_q1e-5.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/graphsage_64d_q1e-5.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/vgae_256d_q1e-5.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/node2vec_128d_p0.5_q1_q1e-5.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/spect_q1e-5.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Clusters Enriched")
ax.set_ylabel("# of clusters")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Cluster/BoxPlot.png',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/DeepWalk_64d_q1e-5_50.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/graphsage_256d_q1e-5_50.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/vgae_128d_q1e-5_50.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/node2vec_256d_p1_q2_q1e-5_50.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/spect_q1e-5_50.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Clusters Enriched")
ax.set_ylabel("# of clusters")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Cluster/BoxPlot.png',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/DeepWalk_64d_q1e-5_50.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/graphsage_256d_q1e-5_50.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/vgae_64d_q1e-5_50.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/node2vec_256d_p1_q2_q1e-5_50.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/spect_q1e-5_50.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Clusters Enriched")
ax.set_ylabel("# of clusters")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Cluster/BoxPlot.png',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/DeepWalk_64d_q1e-5_cellline_count_50.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/graphsage_64d_q1e-5_cellline_count_50.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/vgae_256d_q1e-5_cellline_count_50.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/node2vec_128d_p0.5_q1_q1e-5_cellline_count_50.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/spect_q1e-5_cellline_count_50.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Terms Enriched")
ax.set_ylabel("# of terms")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/Undiffused_Networks/Results/GO_Term_Count_Term/BoxPlot.png',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/DeepWalk_64d_q1e-5_cellline_count_50.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/graphsage_256d_q1e-5_cellline_count_50.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/vgae_128d_q1e-5_cellline_count_50.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/node2vec_256d_p1_q2_q1e-5_cellline_count_50.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/spect_q1e-5_cellline_count_50.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Terms Enriched")
ax.set_ylabel("# of terms")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/ASD_Diffused_Networks/Results/GO_Term_Count_Term/BoxPlot.png',bbox_inches="tight")

# %%
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/DeepWalk_64d_q1e-5_cellline_count_50.txt", "r") as f1:
    DeepWalk = f1.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/graphsage_256d_q1e-5_cellline_count_50.txt", "r") as f2:
    Graphsage = f2.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/vgae_64d_q1e-5_cellline_count_50.txt", "r") as f3:
    VGAE = f3.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/node2vec_256d_p1_q2_q1e-5_cellline_count_50.txt", "r") as f4:
    node2vec = f4.readline().split(",")
with open("/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/spect_q1e-5_cellline_count_50.txt", "r") as f5:
    spect = f5.readline().split(",")

Score = DeepWalk + Graphsage + VGAE + node2vec + spect
Score = [int(i) for i in Score]
Method = ["DeepWalk"] * 55 + ["Graphsage"] * 55 + ["VGAE"] * 55 + ["node2vec"] * 55 + ["spect"] * 55
diction = {"Method":Method, "Score":Score}

df = pd.DataFrame(data = diction)
ax = sns.boxplot(x="Method",y="Score",data=df)
ax.set_xticklabels(["DeepWalk","Graphsage","VGAE","node2vec","Graph Laplacian"],ha='right',rotation=45)
ax.set_title("Num of Terms Enriched")
ax.set_ylabel("# of terms")
ax.set_xlabel("Methods")
plt.savefig('/mnt/dv/wid/projects3/Roy-enhancer-promoter/Zhiwei_Work/GO_Enrichment/CAD_Diffused_Networks/Results/GO_Term_Count_Term/BoxPlot.png',bbox_inches="tight")
